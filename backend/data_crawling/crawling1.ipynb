# %% [markdown]
# https://www.icicibank.com/personal-banking/loans

# %%
# crawling the sitemap url

import requests
from bs4 import BeautifulSoup
from pathlib import Path

OUTPUT_FILE = Path(r"D:\icici_rag\data\urls.txt")
url = "https://www.icicibank.com/personal-banking-sitemap.xml"

headers = {
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

result = requests.get(url, headers = headers)

print(f"Status code: {result.status_code}")

if result.status_code == 200:
    soup = BeautifulSoup(result.content,"lxml-xml")
    urls = [loc.text for loc in soup.find_all("loc")]
    OUTPUT_FILE.parent.mkdir(parents=True, exist_ok=True)
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        for url in urls:
            f.write(url+"\n")
    print(f"saved to {OUTPUT_FILE}")


else:
    print(f"Request failed with status : {result.status_code}")
# Out:
# Status code: 200
# saved to D:\icici_rag\data\urls.txt

# %%
# length of the urls
len(urls)
# Out:
# 4370

# %%
# FILTERING HOME LOAN SITEMAP URLS

home_loan_related_patterns = [
    '/home'
]

home_loan_urls = [url for url in urls if any(pattern in url for pattern in home_loan_related_patterns)]


len(home_loan_urls)
# Out:
# 169

# %%
home_loan_urls
# Out:
# ['https://www.icicibank.com/personal-banking/faq/loan/home-loans-faqs',
#  'https://www.icicibank.com/personal-banking/faq/loan/home-loan-cashback-offer-faqs',
#  'https://www.icicibank.com/personal-banking/faq/insurance/home-insurance-faqs',
#  'https://www.icicibank.com/personal-banking/accounts/home-assure-savings-account',
#  'https://www.icicibank.com/personal-banking/loans/personal-loan/home-renovation',
#  'https://www.icicibank.com/personal-banking/loans/home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pahl-sanction-disbursement',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/interest-rates',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/top-up-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement/document-checklist',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement/legal-valuation',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/service-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/moderate',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/review',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/service-charges1',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/service-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/guaranteed-emergency-credit-line',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/colending-policy',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/required-documents',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/pratham-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/interest-rate',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/subsequent-disbursement',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft-interest-rate',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/moderate',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-interest-rates',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/interest-rate',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/required-documents',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/cgtmse',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/interest-rates',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loans-type',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-specialised-property',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-specialised-property/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan-online-sanction',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/land-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/interest-rate',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/confirming-construction-of-house',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/existing-customers',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/existing-customers/rate-reset',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/review',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft/home-overdraft-faqs',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/mortgage-affinity-banking',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/commercial-property-purchase-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/approved-projects',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/step-up-home-loans',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/step-up-home-loans/step-up-home-loans-faqs',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pragati-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-online',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/track-my-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/documents-required',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/lease-rental-discounting',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/lease-rental-discounting/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/24-hours-topup',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/24-hours-topup/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/saral-housing-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/30-years-tenure-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-propety',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pradhan-mantri-awas-yojna',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/insure',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pa',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pa/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pa/home-loan-balance-transfer-pa',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/repayment',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer/interest-rates',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1/interest-rates',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pre-approved-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-statement',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/extraa-home-loans',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/interest-rate',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/required-documents',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/dummy-calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/valuation-service',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/emi-under-construction',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/emi-under-construction/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/renovation',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pabt-sanction-disbursement',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/escrow-services',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property1',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property1/required-documents',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property1/calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pre-approved-loan-against-property',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/investment-advisory',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan-online-sanction-demo',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/resale-services',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer/documents',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer/fees-and-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/ri-disbursement-documents',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/locat-trans-property-doc-list',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/testtttt',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/money-saver',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/money-saver/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-od',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-improvement',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pre-approved',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loans-faqs',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/affordable-home-loans-faqs',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/documents-required-for-home-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/office-premises-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/office-premises-loan/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/top-up',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/24-hours-top-up-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/insta-top-up-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/insta',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/instant-top-up',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-loan-against-property',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/instant-loan-against-property/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/prepayment-calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/construction-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/affordability-calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan/insta-top-up-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan/insta',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan/24-hrs-top-up-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/penal-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/contact-details',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/penal-and-service-charges',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/emi-calculator',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/interest-rates',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-improvement-loan',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-improvement-loan/index',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/pmay',
#  'https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-instant',
#  'https://www.icicibank.com/personal-banking/loans/home-loan-test',
#  'https://www.icicibank.com/personal-banking/insurance/home-insurance/home-claims',
#  'https://www.icicibank.com/personal-banking/insurance/home-insurance/index',
#  'https://www.icicibank.com/personal-banking/insurance/home-insurance/home-insurance-faqs',
#  'https://www.icicibank.com/personal-banking/insurance/health-insurance/home-claims',
#  'https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-insurance-emailer-disclaimer',
#  'https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-insurance-disclaimer',
#  'https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-claims',
#  'https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/moderate',
#  'https://www.icicibank.com/personal-banking/products/online-safe-banking/loans-index/home-loan',
#  'https://www.icicibank.com/personal-banking/products/online-safe-banking/home-loan',
#  'https://www.icicibank.com/personal-banking/products/online-safe-banking/home-loan0',
#  'https://www.icicibank.com/personal-banking/products/online-safe-banking/homeoffer-index',
#  'https://www.icicibank.com/personal-banking/products/product-revamp/product/loans/home-loan',
#  'https://www.icicibank.com/personal-banking/insta-banking/internet-banking1/home-loan-related',
#  'https://www.icicibank.com/personal-banking/insta-banking/internet-banking/home-loan-related',
#  'https://www.icicibank.com/personal-banking/investments/homefinance-fd',
#  'https://www.icicibank.com/personal-banking/investments/homefinance-fd/disclosure',
#  'https://www.icicibank.com/personal-banking/investments/homefinance-fd/features']

# %% [markdown]
# Filter home loans by categories:

# %%
#Define your target categories with specific patterns
home_loan_categories = {
    # Loan variations and types
    'loan_types': [
        'top-up', 'balance-transfer', 'loan-against-property', 'land-loan',
        'home-renovation', 'home-improvement', 'construction-loan',
        'commercial-property', 'office-premises', 'lease-rental-discounting'
    ],
    
    # Financial details - CRITICAL for RAG
    'rates_interest': [
        'interest-rate', 'interest-rates', 'rates', 'home-loan-interest-rates',
        'home-overdraft-interest-rate', 'service', 'charges', 'forex', 'fees-and-charges', 'service-charges', 'penal-charges', 'charges',
        'fees', 'cost', 'penal-and-service-charges'
    ],
    
    
    # Calculators - Separate category for numerical content
    'calculators_tools': [
        'calculator', 'emi-calculator', 'affordability-calculator',
        'prepayment-calculator', 'dummy-calculator'
    ],
    
    # Eligibility and requirements
    'eligibility_docs': [
        'eligibility', 'documents-required', 'required-documents',
        'document-checklist', 'checklist', 'qualification', 'who-can-apply'
    ],
    
    # Application process - Step-by-step guidance
    'application_process': [
        'apply', 'application', 'process', 'how-to-apply', 'sanction-disbursement',
        'disbursement', 'track-my-loan', 'online-sanction', 'pahl-sanction',
        'hl-sanction', 'pabt-sanction'
    ],
    
    # Policies and terms - Legal context
    'policies_terms': [
        'policy', 'colending-policy', 'terms', 'conditions', 'cgtmse',
        'legal-valuation', 'escrow-services', 'tnc', 't&c', 'legal'
    ],
    
    # FAQs and help - Q&A format content
    'faqs_help': [
        'faqs', 'frequently-asked-questions', 'help', 'faq', 'home-loans-faqs',
        'affordable-home-loans-faqs', 'home-overdraft-faqs', 'step-up-home-loans-faqs'
    ],
    
    # Account management - Existing customers
    'account_management': [
        'existing-customers', 'rate-reset', 'home-loan-statement',
        'repayment', 'prepayment', 'emi-under-construction'
    ],
    
    # Insurance and protection
    'insurance_protection': [
        'insurance', 'insure', 'home-insurance', 'home-claims'
    ],
    
    # Government schemes
    'government_schemes': [
        'pmay', 'pradhan-mantri-awas-yojna', 'government-schemes'
    ],
    
    # Pre-approved offers
    'pre_approved_offers': [
        'pre-approved', 'pre-approved-home-loan', 'pre-approved-loan-against-property'
    ],

    'product_overviews': [
    'home-loan', 'instant-home-loan', 'pratham-home-loan', 'step-up-home-loans',
    'pragati-home-loan', 'express-home-loan', 'extraa-home-loans', 'money-saver',
    '30-years-tenure', 'affordable-home-loans', 'saral-housing-loan', 'index'
    ]
}

def categorize_home_loan_urls(all_urls):
    categorized = {category: [] for category in home_loan_categories.keys()}
    

    
    # Then categorize by content type
    for url in all_urls:
        url_lower = url.lower()
        # categorized_flag = False
        
        for category, patterns in home_loan_categories.items():
            if any(pattern in url_lower for pattern in patterns):
               
                categorized[category].append(url)
                # categorized_flag = True
                break
        
        # If doesn't match specific patterns, put in features_benefits as default
        # if not categorized_flag:
        #     categorized['features_benefits'].append(url)
    
    return categorized

# %% [markdown]
# Review and Validate Your Filtered URLs

# %%
# Get your categorized URLs
categorized_urls = categorize_home_loan_urls(home_loan_urls)

# Review what you got
for category, urls in categorized_urls.items():
    print(f"\n{category.upper()}: {len(urls)} URLs")
    for url in urls[:10]:
        print(f"  - {url}")
    if len(urls) > 3:
        print(f"  ... and {len(urls) - 3} more")
# Out:
# LOAN_TYPES: 62 URLs
#   - https://www.icicibank.com/personal-banking/loans/personal-loan/home-renovation
#   - https://www.icicibank.com/personal-banking/loans/home-loan/top-up-home-loan
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/fees-and-charges
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/interest-rate
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/index
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/required-documents
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/calculator
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/cgtmse
#   - https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/interest-rates
#   ... and 59 more
#
# RATES_INTEREST: 15 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/fees-and-charges
#   - https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/interest-rates
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/service-charges
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/service-charges1
#   - https://www.icicibank.com/personal-banking/loans/home-loan/service-charges
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/interest-rate
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/fees-and-charges
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft-interest-rate
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-interest-rates
#   - https://www.icicibank.com/personal-banking/loans/home-loan/valuation-service
#   ... and 12 more
#
# CALCULATORS_TOOLS: 4 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/dummy-calculator
#   - https://www.icicibank.com/personal-banking/loans/home-loan/prepayment-calculator
#   - https://www.icicibank.com/personal-banking/loans/home-loan/affordability-calculator
#   - https://www.icicibank.com/personal-banking/loans/home-loan/emi-calculator
#   ... and 1 more
#
# ELIGIBILITY_DOCS: 4 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement/document-checklist
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/required-documents
#   - https://www.icicibank.com/personal-banking/loans/home-loan/documents-required
#   - https://www.icicibank.com/personal-banking/loans/home-loan/documents-required-for-home-loan
#   ... and 1 more
#
# APPLICATION_PROCESS: 9 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pahl-sanction-disbursement
#   - https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement
#   - https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement/legal-valuation
#   - https://www.icicibank.com/personal-banking/loans/home-loan/subsequent-disbursement
#   - https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan-online-sanction
#   - https://www.icicibank.com/personal-banking/loans/home-loan/track-my-loan
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pabt-sanction-disbursement
#   - https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan-online-sanction-demo
#   - https://www.icicibank.com/personal-banking/loans/home-loan/ri-disbursement-documents
#   ... and 6 more
#
# POLICIES_TERMS: 1 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/colending-policy
#
# FAQS_HELP: 8 URLs
#   - https://www.icicibank.com/personal-banking/faq/loan/home-loans-faqs
#   - https://www.icicibank.com/personal-banking/faq/loan/home-loan-cashback-offer-faqs
#   - https://www.icicibank.com/personal-banking/faq/insurance/home-insurance-faqs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft/home-overdraft-faqs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/step-up-home-loans/step-up-home-loans-faqs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loans-faqs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/affordable-home-loans-faqs
#   - https://www.icicibank.com/personal-banking/insurance/home-insurance/home-insurance-faqs
#   ... and 5 more
#
# ACCOUNT_MANAGEMENT: 6 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/existing-customers
#   - https://www.icicibank.com/personal-banking/loans/home-loan/existing-customers/rate-reset
#   - https://www.icicibank.com/personal-banking/loans/home-loan/repayment
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-statement
#   - https://www.icicibank.com/personal-banking/loans/home-loan/emi-under-construction
#   - https://www.icicibank.com/personal-banking/loans/home-loan/emi-under-construction/index
#   ... and 3 more
#
# INSURANCE_PROTECTION: 8 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/insure
#   - https://www.icicibank.com/personal-banking/insurance/home-insurance/home-claims
#   - https://www.icicibank.com/personal-banking/insurance/home-insurance/index
#   - https://www.icicibank.com/personal-banking/insurance/health-insurance/home-claims
#   - https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-insurance-emailer-disclaimer
#   - https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-insurance-disclaimer
#   - https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-claims
#   - https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/moderate
#   ... and 5 more
#
# GOVERNMENT_SCHEMES: 2 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pradhan-mantri-awas-yojna
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pmay
#
# PRE_APPROVED_OFFERS: 1 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pre-approved-home-loan
#
# PRODUCT_OVERVIEWS: 45 URLs
#   - https://www.icicibank.com/personal-banking/loans/home-loan
#   - https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan
#   - https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/index
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/moderate
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/review
#   - https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/index
#   - https://www.icicibank.com/personal-banking/loans/home-loan/guaranteed-emergency-credit-line
#   - https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/pratham-home-loan
#   - https://www.icicibank.com/personal-banking/loans/home-loan/moderate
#   ... and 42 more

# %%
# classified_urls
classified_urls=0
for key, urls in categorized_urls.items():
    classified_urls+=len(urls)
classified_urls
# Out:
# 165

# %% [markdown]
# Implement Category-Specific Content Extraction

# %%
def extract_content_by_category(soup, category):
    """Extract relevant content based on category"""
    
    # Remove unwanted elements
    for element in soup(['script', 'style', 'nav', 'footer', 'header', 'menu']):
        element.decompose()

    return soup.get_text(strip=True)

# %% [markdown]
# crawl with enhanced structure

# %%
import time
import requests
from bs4 import BeautifulSoup
def crawl_home_loan_comprehensive(categorized_urls, delay = 3):
    all_content=[]
    for category, urls in categorized_urls.items():
        if not urls:
            continue
        print(f"Crawling {category}:{len(urls)} URLs")
        for i, url in enumerate(urls):
            print(f"processsing {i+1}/{len(urls)} : {url}")
            content = extract_home_loan_content_enhanced(url, category)
            if content:
                all_content.append(content)
            time.sleep(delay)
    return all_content



def extract_home_loan_content_enhanced(url, category):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    try:
        response = requests.get(url, headers = headers)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            content = {
                'url': url,
                'category': category,
                'title': soup.find('title').text if soup.find('title') else '',
                'content': extract_content_by_category(soup, category),
                'content_length': len(soup.get_text(strip=True)),
                'last_scraped': time.strftime('%Y-%m-%d %H:%M:%S')
            }
            return content
        else:
            print(f"Failed: Status {response.status_code}")
            return None
    except Exception as e:
        print(f"Error: {e}")
        return None

# %% [markdown]
# Prepare Data for RAG

# %%
# def prepare_home_loan_rag_data(scraped_data):
#     rag_chunks = []
#     for item in scraped_data:
#         content = item['content']
#         chunks = content.split('.')
#         for i, chunk in enumerate(chunks):
#             if len(chunk.strip()) > 50:
#                 rag_chunk = {
#                     'id': f"home_loan_{item['category']}_{hash(item['url'])}_{i}",
#                     'content': chunk.strip(),
#                     'metadata': {
#                         'loan_type': 'home_loan',
#                         'category': item['category'],
#                         'source_url': item['url'],
#                         'title': item['title'],
#                         'chunk_index': i
#                     }
#                 }
#                 rag_chunks.append(rag_chunk)

#     return rag_chunks

# %%
print("Starting Home Loan Data Collection")
# Out:
# Starting Home Loan Data Collection

# %%
import requests
from bs4 import BeautifulSoup
import time
import json


def extract_home_loan_content(url, category):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Extract structured content based on category
            content = {
                'url': url,
                'category': category,
                'title': soup.find('title').text if soup.find('title') else '',
                'content': extract_relevant_content(soup, category),
                'last_scraped': time.strftime('%Y-%m-%d %H:%M:%S')
            }
            return content
        else:
            print(f"Failed to fetch {url}: Status {response.status_code}")
            return None
    except Exception as e:
        print(f"Error processing {url}: {e}")
        return None

def extract_relevant_content(soup, category):
    # Remove scripts, styles, and navigation elements
    for element in soup(['script', 'style', 'nav', 'footer', 'header']):
        element.decompose()

    return soup.get_text(strip=True)

# %%
print("Starting Home Loan Data Collection...")
categorized_urls = categorize_home_loan_urls(home_loan_urls)
scraped_data = crawl_home_loan_comprehensive(categorized_urls)
#rag_chunks = prepare_home_loan_rag_data(scraped_data)

#Save results
import json
import os 
save_path = r"D:\icici_rag\data"
os.makedirs(save_path, exist_ok=True)
file_path = os.path.join(save_path, 'home_loan_raw_data_final.json')
with open(file_path, 'w',encoding='utf-8') as f:
    json.dump(scraped_data, f, indent=2)

# with open('home_loan_rag_chunks.json', 'w') as f:
#     json.dump(rag_chunks, f, indent=2)

print(f"Collected {len(scraped_data)} documents")
# print(f"Created {len(rag_chunks)} RAG chunks")
# Out:
# Starting Home Loan Data Collection...
# Crawling loan_types:62 URLs
# processsing 1/62 : https://www.icicibank.com/personal-banking/loans/personal-loan/home-renovation
# processsing 2/62 : https://www.icicibank.com/personal-banking/loans/home-loan/top-up-home-loan
# processsing 3/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property
# processsing 4/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/fees-and-charges
# processsing 5/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/interest-rate
# processsing 6/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/index
# processsing 7/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/required-documents
# processsing 8/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/calculator
# processsing 9/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/cgtmse
# processsing 10/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property/interest-rates
# Failed: Status 404
# processsing 11/62 : https://www.icicibank.com/personal-banking/loans/home-loan/land-loan
# processsing 12/62 : https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/interest-rate
# processsing 13/62 : https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/fees-and-charges
# processsing 14/62 : https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/index
# processsing 15/62 : https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/confirming-construction-of-house
# processsing 16/62 : https://www.icicibank.com/personal-banking/loans/home-loan/land-loan/calculator
# processsing 17/62 : https://www.icicibank.com/personal-banking/loans/home-loan/commercial-property-purchase-loan
# processsing 18/62 : https://www.icicibank.com/personal-banking/loans/home-loan/lease-rental-discounting
# processsing 19/62 : https://www.icicibank.com/personal-banking/loans/home-loan/lease-rental-discounting/index
# processsing 20/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pa
# processsing 21/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pa/index
# processsing 22/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pa/home-loan-balance-transfer-pa
# processsing 23/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer
# processsing 24/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer/interest-rates
# processsing 25/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer/fees-and-charges
# processsing 26/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer/index
# processsing 27/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1
# processsing 28/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1/interest-rates
# processsing 29/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1/fees-and-charges
# processsing 30/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-balance-transfer1/index
# processsing 31/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/calculator
# processsing 32/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/fees-and-charges
# processsing 33/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/interest-rate
# processsing 34/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-plus-top-up/required-documents
# processsing 35/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property1
# processsing 36/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property1/required-documents
# processsing 37/62 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-property1/calculator
# processsing 38/62 : https://www.icicibank.com/personal-banking/loans/home-loan/pre-approved-loan-against-property
# processsing 39/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer
# processsing 40/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer/index
# processsing 41/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer/documents
# processsing 42/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer/fees-and-charges
# processsing 43/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-improvement
# processsing 44/62 : https://www.icicibank.com/personal-banking/loans/home-loan/balance-transfer-pre-approved
# processsing 45/62 : https://www.icicibank.com/personal-banking/loans/home-loan/office-premises-loan
# processsing 46/62 : https://www.icicibank.com/personal-banking/loans/home-loan/office-premises-loan/index
# processsing 47/62 : https://www.icicibank.com/personal-banking/loans/home-loan/top-up
# processsing 48/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up
# processsing 49/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/24-hours-top-up-loan
# processsing 50/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/index
# processsing 51/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/insta-top-up-loan
# processsing 52/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/insta
# processsing 53/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-top-up/instant-top-up
# processsing 54/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-loan-against-property
# processsing 55/62 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-loan-against-property/index
# processsing 56/62 : https://www.icicibank.com/personal-banking/loans/home-loan/construction-loan
# processsing 57/62 : https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan
# processsing 58/62 : https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan/insta-top-up-loan
# processsing 59/62 : https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan/insta
# processsing 60/62 : https://www.icicibank.com/personal-banking/loans/home-loan/top-up-loan/24-hrs-top-up-loan
# processsing 61/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-improvement-loan
# processsing 62/62 : https://www.icicibank.com/personal-banking/loans/home-loan/home-improvement-loan/index
# Crawling rates_interest:15 URLs
# processsing 1/15 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/fees-and-charges
# processsing 2/15 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/interest-rates
# processsing 3/15 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/service-charges
# processsing 4/15 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/service-charges1
# processsing 5/15 : https://www.icicibank.com/personal-banking/loans/home-loan/service-charges
# processsing 6/15 : https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/interest-rate
# processsing 7/15 : https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/fees-and-charges
# processsing 8/15 : https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft-interest-rate
# processsing 9/15 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-interest-rates
# processsing 10/15 : https://www.icicibank.com/personal-banking/loans/home-loan/valuation-service
# processsing 11/15 : https://www.icicibank.com/personal-banking/loans/home-loan/escrow-services
# processsing 12/15 : https://www.icicibank.com/personal-banking/loans/home-loan/resale-services
# processsing 13/15 : https://www.icicibank.com/personal-banking/loans/home-loan/penal-charges
# processsing 14/15 : https://www.icicibank.com/personal-banking/loans/home-loan/penal-and-service-charges
# processsing 15/15 : https://www.icicibank.com/personal-banking/loans/home-loan/interest-rates
# Crawling calculators_tools:4 URLs
# processsing 1/4 : https://www.icicibank.com/personal-banking/loans/home-loan/dummy-calculator
# processsing 2/4 : https://www.icicibank.com/personal-banking/loans/home-loan/prepayment-calculator
# processsing 3/4 : https://www.icicibank.com/personal-banking/loans/home-loan/affordability-calculator
# processsing 4/4 : https://www.icicibank.com/personal-banking/loans/home-loan/emi-calculator
# Crawling eligibility_docs:4 URLs
# processsing 1/4 : https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement/document-checklist
# processsing 2/4 : https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/required-documents
# processsing 3/4 : https://www.icicibank.com/personal-banking/loans/home-loan/documents-required
# processsing 4/4 : https://www.icicibank.com/personal-banking/loans/home-loan/documents-required-for-home-loan
# Crawling application_process:9 URLs
# processsing 1/9 : https://www.icicibank.com/personal-banking/loans/home-loan/pahl-sanction-disbursement
# processsing 2/9 : https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement
# processsing 3/9 : https://www.icicibank.com/personal-banking/loans/home-loan/hl-sanction-disbursement/legal-valuation
# processsing 4/9 : https://www.icicibank.com/personal-banking/loans/home-loan/subsequent-disbursement
# processsing 5/9 : https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan-online-sanction
# Failed: Status 404
# processsing 6/9 : https://www.icicibank.com/personal-banking/loans/home-loan/track-my-loan
# processsing 7/9 : https://www.icicibank.com/personal-banking/loans/home-loan/pabt-sanction-disbursement
# processsing 8/9 : https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan-online-sanction-demo
# processsing 9/9 : https://www.icicibank.com/personal-banking/loans/home-loan/ri-disbursement-documents
# Crawling policies_terms:1 URLs
# processsing 1/1 : https://www.icicibank.com/personal-banking/loans/home-loan/colending-policy
# Crawling faqs_help:8 URLs
# processsing 1/8 : https://www.icicibank.com/personal-banking/faq/loan/home-loans-faqs
# processsing 2/8 : https://www.icicibank.com/personal-banking/faq/loan/home-loan-cashback-offer-faqs
# processsing 3/8 : https://www.icicibank.com/personal-banking/faq/insurance/home-insurance-faqs
# processsing 4/8 : https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft/home-overdraft-faqs
# processsing 5/8 : https://www.icicibank.com/personal-banking/loans/home-loan/step-up-home-loans/step-up-home-loans-faqs
# processsing 6/8 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loans-faqs
# processsing 7/8 : https://www.icicibank.com/personal-banking/loans/home-loan/affordable-home-loans-faqs
# processsing 8/8 : https://www.icicibank.com/personal-banking/insurance/home-insurance/home-insurance-faqs
# Crawling account_management:6 URLs
# processsing 1/6 : https://www.icicibank.com/personal-banking/loans/home-loan/existing-customers
# processsing 2/6 : https://www.icicibank.com/personal-banking/loans/home-loan/existing-customers/rate-reset
# processsing 3/6 : https://www.icicibank.com/personal-banking/loans/home-loan/repayment
# processsing 4/6 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-statement
# processsing 5/6 : https://www.icicibank.com/personal-banking/loans/home-loan/emi-under-construction
# processsing 6/6 : https://www.icicibank.com/personal-banking/loans/home-loan/emi-under-construction/index
# Crawling insurance_protection:8 URLs
# processsing 1/8 : https://www.icicibank.com/personal-banking/loans/home-loan/insure
# processsing 2/8 : https://www.icicibank.com/personal-banking/insurance/home-insurance/home-claims
# processsing 3/8 : https://www.icicibank.com/personal-banking/insurance/home-insurance/index
# processsing 4/8 : https://www.icicibank.com/personal-banking/insurance/health-insurance/home-claims
# processsing 5/8 : https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-insurance-emailer-disclaimer
# processsing 6/8 : https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-insurance-disclaimer
# processsing 7/8 : https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/home-claims
# processsing 8/8 : https://www.icicibank.com/personal-banking/insurance/general-insurance/home-insurance/moderate
# Crawling government_schemes:2 URLs
# processsing 1/2 : https://www.icicibank.com/personal-banking/loans/home-loan/pradhan-mantri-awas-yojna
# processsing 2/2 : https://www.icicibank.com/personal-banking/loans/home-loan/pmay
# Crawling pre_approved_offers:1 URLs
# processsing 1/1 : https://www.icicibank.com/personal-banking/loans/home-loan/pre-approved-home-loan
# Crawling product_overviews:45 URLs
# processsing 1/45 : https://www.icicibank.com/personal-banking/loans/home-loan
# processsing 2/45 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan
# processsing 3/45 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-loan/index
# processsing 4/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation
# processsing 5/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/moderate
# processsing 6/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/review
# processsing 7/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-variation/index
# processsing 8/45 : https://www.icicibank.com/personal-banking/loans/home-loan/guaranteed-emergency-credit-line
# processsing 9/45 : https://www.icicibank.com/personal-banking/loans/home-loan/pratham-home-loan/pratham-home-loan
# processsing 10/45 : https://www.icicibank.com/personal-banking/loans/home-loan/moderate
# processsing 11/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loans-type
# processsing 12/45 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-specialised-property
# processsing 13/45 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-specialised-property/index
# processsing 14/45 : https://www.icicibank.com/personal-banking/loans/home-loan/review
# processsing 15/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-overdraft
# processsing 16/45 : https://www.icicibank.com/personal-banking/loans/home-loan/mortgage-affinity-banking
# processsing 17/45 : https://www.icicibank.com/personal-banking/loans/home-loan/approved-projects
# processsing 18/45 : https://www.icicibank.com/personal-banking/loans/home-loan/step-up-home-loans
# processsing 19/45 : https://www.icicibank.com/personal-banking/loans/home-loan/pragati-home-loan
# processsing 20/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-online
# processsing 21/45 : https://www.icicibank.com/personal-banking/loans/home-loan/24-hours-topup
# processsing 22/45 : https://www.icicibank.com/personal-banking/loans/home-loan/24-hours-topup/index
# processsing 23/45 : https://www.icicibank.com/personal-banking/loans/home-loan/saral-housing-loan
# processsing 24/45 : https://www.icicibank.com/personal-banking/loans/home-loan/30-years-tenure-home-loan
# processsing 25/45 : https://www.icicibank.com/personal-banking/loans/home-loan/loan-against-propety
# processsing 26/45 : https://www.icicibank.com/personal-banking/loans/home-loan/index
# processsing 27/45 : https://www.icicibank.com/personal-banking/loans/home-loan/extraa-home-loans
# processsing 28/45 : https://www.icicibank.com/personal-banking/loans/home-loan/express-home-loan
# Failed: Status 404
# processsing 29/45 : https://www.icicibank.com/personal-banking/loans/home-loan/renovation
# processsing 30/45 : https://www.icicibank.com/personal-banking/loans/home-loan/investment-advisory
# processsing 31/45 : https://www.icicibank.com/personal-banking/loans/home-loan/locat-trans-property-doc-list
# processsing 32/45 : https://www.icicibank.com/personal-banking/loans/home-loan/testtttt
# processsing 33/45 : https://www.icicibank.com/personal-banking/loans/home-loan/money-saver
# Failed: Status 404
# processsing 34/45 : https://www.icicibank.com/personal-banking/loans/home-loan/money-saver/index
# Failed: Status 404
# processsing 35/45 : https://www.icicibank.com/personal-banking/loans/home-loan/instant-home-od
# processsing 36/45 : https://www.icicibank.com/personal-banking/loans/home-loan/contact-details
# processsing 37/45 : https://www.icicibank.com/personal-banking/loans/home-loan/home-loan-instant
# processsing 38/45 : https://www.icicibank.com/personal-banking/loans/home-loan-test
# processsing 39/45 : https://www.icicibank.com/personal-banking/products/online-safe-banking/loans-index/home-loan
# processsing 40/45 : https://www.icicibank.com/personal-banking/products/online-safe-banking/home-loan
# processsing 41/45 : https://www.icicibank.com/personal-banking/products/online-safe-banking/home-loan0
# processsing 42/45 : https://www.icicibank.com/personal-banking/products/online-safe-banking/homeoffer-index
# processsing 43/45 : https://www.icicibank.com/personal-banking/products/product-revamp/product/loans/home-loan
# processsing 44/45 : https://www.icicibank.com/personal-banking/insta-banking/internet-banking1/home-loan-related
# processsing 45/45 : https://www.icicibank.com/personal-banking/insta-banking/internet-banking/home-loan-related
# Collected 160 documents
